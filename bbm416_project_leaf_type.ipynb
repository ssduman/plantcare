# %% [markdown]
# # kaggle

# %%
# https://www.kaggle.com/general/74235
# !pip -q install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d abdallahalidev/plantvillage-dataset # Copy API command

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # unzip

# %%
# https://drive.google.com/file/d/1hW4otiVDOKjfl2K3UY2fFbMH2j7FyqVw/view?usp=sharing
# !unzip -q drive/MyDrive/datasets/plantvillage-dataset.zip

# %% [markdown]
# # import

# %%
import os
import cv2
import h5py
import glob
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from tqdm import tqdm
from matplotlib import cm
from matplotlib import pyplot as plt
from torchvision import datasets, transforms, models
from torchsummary import summary
from sklearn.metrics import confusion_matrix
from matplotlib.image import imread
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR

# %% [markdown]
# # dataset

# %% [markdown]
# ## all

# %%
classes = ["healthy", "infected"]
files = glob.glob("plantvillage dataset/**/**/*.*")
len(files), list(np.random.choice(files, 10))
# Out:
# (162916,
#  ['plantvillage dataset/segmented/Pepper,_bell___healthy/be4bdbf7-8e8f-4cd6-ba14-15d4a27dfe00___JR_HL 7609_final_masked.jpg',
#   'plantvillage dataset/color/Tomato___Bacterial_spot/3b4b04a8-171b-4ebe-9dec-d1e476605354___GCREC_Bact.Sp 5855.JPG',
#   'plantvillage dataset/segmented/Strawberry___healthy/a845e8b5-bd7a-4438-8936-e3191d2d3ba5___RS_HL 1653_final_masked.jpg',
#   'plantvillage dataset/grayscale/Orange___Haunglongbing_(Citrus_greening)/26454175-626b-436b-b59c-396872381437___UF.Citrus_HLB_Lab 0691.JPG',
#   'plantvillage dataset/segmented/Tomato___Bacterial_spot/96e66b34-f4b6-40d7-9459-53fd4da64a9f___GCREC_Bact.Sp 5793_final_masked.jpg',
#   'plantvillage dataset/color/Tomato___Target_Spot/320a66eb-2f38-4db4-bd2f-3fbb298a43bf___Com.G_TgS_FL 8025.JPG',
#   'plantvillage dataset/color/Tomato___Spider_mites Two-spotted_spider_mite/3ff572ac-0f2f-494a-9c64-99ae63d318ef___Com.G_SpM_FL 1242.JPG',
#   'plantvillage dataset/color/Tomato___Tomato_mosaic_virus/5c049070-cf7f-4508-8e61-c5efb64bca3c___PSU_CG 2326.JPG',
#   'plantvillage dataset/color/Orange___Haunglongbing_(Citrus_greening)/458349d0-395f-4063-9449-d56d05948482___UF.Citrus_HLB_Lab 1508.JPG',
#   'plantvillage dataset/grayscale/Corn_(maize)___Common_rust_/RS_Rust 2329.JPG'])

# %%
path = "plantvillage dataset/color/Tomato___healthy/0c8c9c80-b7e0-47a7-81d3-b5a2174e545d___GH_HL Leaf 496.1.JPG"
img = cv2.imread(path, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
plt.tight_layout()
plt.axis("off")
plt.show()
# Out:
# (256, 256, 3)

# %%
path = "plantvillage dataset/color/Tomato___Bacterial_spot/12e9560a-01a5-4d97-a911-409c11cd0301___GCREC_Bact.Sp 3117.JPG"
img = cv2.imread(path, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
plt.tight_layout()
plt.axis("off")
plt.show()
# Out:
# (256, 256, 3)

# %% [markdown]
# ## color

# %%
classes = ["healthy", "infected"]
leaf_types = set()
leaf_types_count = {}

color = glob.glob("plantvillage dataset/color/**/*.*")

for l in color:
    leaf = l.split("___", 1)[0].split("/")[2]
    leaf_types.add(leaf)
    if leaf not in leaf_types_count:
        leaf_types_count[leaf] = 1
    else:
        leaf_types_count[leaf] += 1
leaf_types = sorted(list(leaf_types))
leaf_types_map = {k: v for v, k in enumerate(leaf_types)}

np.random.shuffle(color)

len(color), color[:10], leaf_types_count
# Out:
# (54305,
#  ['plantvillage dataset/color/Tomato___Bacterial_spot/15a1998e-4b4d-446b-98e7-46ed98119495___UF.GRC_BS_Lab Leaf 0222.JPG',
#   'plantvillage dataset/color/Potato___Early_blight/524142aa-78fb-4fab-895c-ddb993d07479___RS_Early.B 7435.JPG',
#   'plantvillage dataset/color/Blueberry___healthy/a5f15c32-bd8a-4f32-90ae-4fa0f7711cd8___RS_HL 0572.JPG',
#   'plantvillage dataset/color/Soybean___healthy/27686854-57d7-49f5-8b85-41d9b663b5d0___RS_HL 7188.JPG',
#   'plantvillage dataset/color/Tomato___Tomato_Yellow_Leaf_Curl_Virus/5a83bed0-6cb4-4ccf-a7d9-631c13a1a140___YLCV_GCREC 2229.JPG',
#   'plantvillage dataset/color/Tomato___Leaf_Mold/4d65825b-367d-4f8e-aa17-c19ee1e631e1___Crnl_L.Mold 6954.JPG',
#   'plantvillage dataset/color/Blueberry___healthy/f8067138-62a9-4707-8c2f-412ef4a6aa78___RS_HL 5486.JPG',
#   'plantvillage dataset/color/Soybean___healthy/d3262cd0-7223-414b-b608-1507848973e0___RS_HL 6401.JPG',
#   'plantvillage dataset/color/Tomato___Bacterial_spot/c787ded5-7722-4419-a5d9-8f4404f68ee4___GCREC_Bact.Sp 3800.JPG',
#   'plantvillage dataset/color/Strawberry___Leaf_scorch/f95d6e54-a621-4741-88d2-d217899a66f0___RS_L.Scorch 1135.JPG'],
#  {'Apple': 3171,
#   'Blueberry': 1502,
#   'Cherry_(including_sour)': 1906,
#   'Corn_(maize)': 3852,
#   'Grape': 4062,
#   'Orange': 5507,
#   'Peach': 2657,
#   'Pepper,_bell': 2475,
#   'Potato': 2152,
#   'Raspberry': 371,
#   'Soybean': 5090,
#   'Squash': 1835,
#   'Strawberry': 1565,
#   'Tomato': 18160})

# %%
split = int(len(color) * 0.8)
train_path = color[:split]
test_path = color[split:]
len(color), len(train_path), len(test_path)
# Out:
# (54305, 43444, 10861)

# %% [markdown]
# ## segmented

# %%
path = "plantvillage dataset/segmented/Apple___Black_rot/0ca16873-eeac-47e9-9a87-1859950daab7___JR_FrgE.S 2835_final_masked.jpg"
img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img_np = np.array(img_gray)
img_np[img_gray < 25] = 0

ys, xs = np.nonzero(img_np)
xsmin, xsmax, ysmin, ysmax = xs.argmin(), xs.argmax(), ys.argmin(), ys.argmax()
print((xs[xsmin] / 256, ys[ysmin] / 256), (xs[xsmax] / 256, ys[ysmax] / 256))

cv2.rectangle(img, (xs[xsmin], ys[ysmin]), (xs[xsmax], ys[ysmax]), (255, 255, 0), 4)
fig, axs = plt.subplots(1, figsize=(15, 6))
axs.set_xticks([])
axs.set_yticks([])
axs.imshow(img)
plt.show()
# Out:
# (0.08203125, 0.06640625) (0.92578125, 0.9375)

# %% [markdown]
# # train

# %% [markdown]
# ## functions

# %%
class PlantDataset(torch.utils.data.Dataset):
    def __init__(self, data_path, transform, leaf_types_map=None):
        self.data_path = data_path
        self.transform = transform
        self.imgs = []
        self.targets = []
        self.leaf_types_map = leaf_types_map

        for d in self.data_path:
            # img = Image.open(d)
            # img = np.array(img.convert("RGB"))
            # if self.transform:
            #     img = self.transform(img)
            # self.imgs.append(img)

            if self.leaf_types_map is None:
                p1 = d.split("___", 1)[1]
                if p1.split("/", 1)[0] == "healthy":
                    self.targets.append(0)
                else:
                    self.targets.append(1)
            else:
                leaf_type = d.split("___", 1)[0].split("/")[2]
                self.targets.append(self.leaf_types_map[leaf_type])
        
        # self.imgs = np.array(all_color_images)
        self.targets = np.array(self.targets)

    def __len__(self):
        return len(self.data_path)

    def __getitem__(self, idx):
        img = Image.open(self.data_path[idx])
        img = np.array(img.convert("RGB"))
        if self.transform:
           img = self.transform(img)
        
        return img, self.targets[idx]

# %%
def train(model, device, train_loader, optimizer, criterion, epoch):
    model.train()
    running_loss = 0.0
    
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device, dtype=torch.float), target.to(device)
        
        optimizer.zero_grad()
        
        output = model(data)
        
        _, preds = torch.max(output, 1)
        loss = criterion(output, target)
        
        running_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        
        if batch_idx % 70 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch + 1, 
                    batch_idx * len(data), 
                    len(train_loader.dataset),
                    100. * batch_idx / len(train_loader), 
                    loss.item()
                )
            )
    
    return running_loss / batch_idx

def test(model, device, test_loader, criterion, leaftype=False):
    model.eval()
    test_loss = 0
    correct = 0
    if not leaftype:
        confusion_matrix = torch.zeros(len(classes), len(classes))
    else:
        confusion_matrix = torch.zeros(len(leaf_types_map), len(leaf_types_map))
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device, dtype=torch.float), target.to(device)
            output = model(data)
            
            _, preds = torch.max(output, 1)
            for t, p in zip(target.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

            test_loss += criterion(output, target).item()
            
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
            test_loss, 
            correct, 
            len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)
        )
    )
    
    return correct / len(test_loader.dataset), confusion_matrix

# %% [markdown]
# ## our model

# %%
class Net(nn.Module):
    def __init__(self, out_size):
        super(Net, self).__init__()
        self.out_size = out_size

        self.conv1 = nn.Conv2d(3, 16, 3, 1)
        self.conv2 = nn.Conv2d(16, 32, 5, 1)
        self.conv3 = nn.Conv2d(32, 48, 5, 1)
        self.conv4 = nn.Conv2d(48, 64, 5, 1)

        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout(0.5)

        self.fc1 = nn.Linear(64 * 28 * 28, 32 * 8 * 8) # 50.176 x 2.048
        self.fc2 = nn.Linear(32 * 8 * 8, 1024)         #  2.048 x 1024
        self.fc3 = nn.Linear(1024, out_size)           #   1024 x 2
    
    def forward(self, x):
        # x -> [batch_size, channel, width, height]
        # x -> [128, 3, 256, 256]
        
        x = self.relu(self.conv1(x)) # x -> [128, 16, 254, 254]
        x = self.relu(self.conv2(x)) # x -> [128, 32, 250, 250]
        x = self.pool(x)             # x -> [128, 32, 125, 125]
        x = self.relu(self.conv3(x)) # x -> [128, 48, 121, 121]
        x = self.pool(x)             # x -> [128, 48,  60,  60]
        x = self.relu(self.conv4(x)) # x -> [128, 64,  56,  56]
        x = self.pool(x)             # x -> [128, 64,  28,  28]
        
        x = torch.flatten(x, 1)      # x -> [128, 64 * 28 * 28]
        
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x

# %% [markdown]
# ### healthy/infected

# %%
batch_size = 128

transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = PlantDataset(train_path, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

test_dataset = PlantDataset(test_path, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net(2).to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=1, gamma=0.7)

loss_values = []
accuracy_values = []
test(model, device, test_loader, criterion)
for epoch in range(5):
    train_loss = train(model, device, train_loader, optimizer, criterion, epoch)
    loss_values.append(train_loss)

    test_acc, confusion_matrix = test(model, device, test_loader, criterion)
    accuracy_values.append(test_acc)

    scheduler.step()

torch.save(model.state_dict(), "plant_model.pth")

df_cm = pd.DataFrame(confusion_matrix.numpy(), index=classes, columns=classes)
plt.figure(figsize=(10, 10))
sns.heatmap(df_cm, annot=True)
plt.show()
# Out:
# Test set: Average loss: 0.0054, Accuracy: 2980/10861 (27%)
#
# Train Epoch: 1 [0/43444 (0%)]	Loss: 0.697209
# Train Epoch: 1 [8960/43444 (21%)]	Loss: 0.448247
# Train Epoch: 1 [17920/43444 (41%)]	Loss: 0.188988
# Train Epoch: 1 [26880/43444 (62%)]	Loss: 0.122707
# Train Epoch: 1 [35840/43444 (83%)]	Loss: 0.170428
#
# Test set: Average loss: 0.0009, Accuracy: 10319/10861 (95%)
#
# Train Epoch: 2 [0/43444 (0%)]	Loss: 0.102146
# Train Epoch: 2 [8960/43444 (21%)]	Loss: 0.044835
# Train Epoch: 2 [17920/43444 (41%)]	Loss: 0.129202
# Train Epoch: 2 [26880/43444 (62%)]	Loss: 0.127374
# Train Epoch: 2 [35840/43444 (83%)]	Loss: 0.026181
#
# Test set: Average loss: 0.0006, Accuracy: 10445/10861 (96%)
#
# Train Epoch: 3 [0/43444 (0%)]	Loss: 0.092414
# Train Epoch: 3 [8960/43444 (21%)]	Loss: 0.021140
# Train Epoch: 3 [17920/43444 (41%)]	Loss: 0.033226
# Train Epoch: 3 [26880/43444 (62%)]	Loss: 0.014823
# Train Epoch: 3 [35840/43444 (83%)]	Loss: 0.071084
#
# Test set: Average loss: 0.0003, Accuracy: 10610/10861 (98%)
#
# Train Epoch: 4 [0/43444 (0%)]	Loss: 0.044496
# Train Epoch: 4 [8960/43444 (21%)]	Loss: 0.017547
# Train Epoch: 4 [17920/43444 (41%)]	Loss: 0.038820
# Train Epoch: 4 [26880/43444 (62%)]	Loss: 0.018610
# Train Epoch: 4 [35840/43444 (83%)]	Loss: 0.025116
#
# Test set: Average loss: 0.0003, Accuracy: 10644/10861 (98%)
#
# Train Epoch: 5 [0/43444 (0%)]	Loss: 0.008343
# Train Epoch: 5 [8960/43444 (21%)]	Loss: 0.007636
# Train Epoch: 5 [17920/43444 (41%)]	Loss: 0.013235
# Train Epoch: 5 [26880/43444 (62%)]	Loss: 0.015001
# Train Epoch: 5 [35840/43444 (83%)]	Loss: 0.000829
#
# Test set: Average loss: 0.0003, Accuracy: 10667/10861 (98%)

# %%
_, ax = plt.subplots(figsize=(10, 5))
ax.plot(np.arange(1, 6).astype(int), loss_values, label="train loss")
ax.plot(np.arange(1, 6).astype(int), accuracy_values, label="test accuracy")
plt.xlabel('Epochs')
plt.ylabel('Loss and Acc')
plt.title('Train Loss and Test Accuracy')
plt.legend()
plt.show()

# %%
summary(model, input_size=(3, 256, 256), batch_size=128)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [128, 16, 254, 254]             448
#               ReLU-2        [128, 16, 254, 254]               0
#             Conv2d-3        [128, 32, 250, 250]          12,832
#               ReLU-4        [128, 32, 250, 250]               0
#          MaxPool2d-5        [128, 32, 125, 125]               0
#             Conv2d-6        [128, 48, 121, 121]          38,448
#               ReLU-7        [128, 48, 121, 121]               0
#          MaxPool2d-8          [128, 48, 60, 60]               0
#             Conv2d-9          [128, 64, 56, 56]          76,864
#              ReLU-10          [128, 64, 56, 56]               0
#         MaxPool2d-11          [128, 64, 28, 28]               0
#            Linear-12                [128, 2048]     102,762,496
#              ReLU-13                [128, 2048]               0
#           Dropout-14                [128, 2048]               0
#            Linear-15                [128, 1024]       2,098,176
#              ReLU-16                [128, 1024]               0
#            Linear-17                   [128, 2]           2,050
# ================================================================
# Total params: 104,991,314
# Trainable params: 104,991,314
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 96.00
# Forward/backward pass size (MB): 8401.00
# Params size (MB): 400.51
# Estimated Total Size (MB): 8897.51
# ----------------------------------------------------------------

# %% [markdown]
# ### leaf type

# %%
batch_size = 128

transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = PlantDataset(train_path, transform, leaf_types_map)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

test_dataset = PlantDataset(test_path, transform, leaf_types_map)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net(len(leaf_types_map)).to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=1, gamma=0.7)

loss_values = []
accuracy_values = []
test(model, device, test_loader, criterion, True)
for epoch in range(5):
    train_loss = train(model, device, train_loader, optimizer, criterion, epoch)
    loss_values.append(train_loss)

    test_acc, confusion_matrix = test(model, device, test_loader, criterion, True)
    accuracy_values.append(test_acc)

    scheduler.step()

torch.save(model.state_dict(), "plant_model.pth")

df_cm = pd.DataFrame(confusion_matrix.numpy(), index=leaf_types, columns=leaf_types)
plt.figure(figsize=(10, 10))
sns.heatmap(df_cm, annot=True)
plt.show()
# Out:
# Test set: Average loss: 0.0204, Accuracy: 1025/10861 (9.44%)
#
# Train Epoch: 1 [0/43444 (0%)]	Loss: 2.637748
# Train Epoch: 1 [8960/43444 (21%)]	Loss: 1.378534
# Train Epoch: 1 [17920/43444 (41%)]	Loss: 0.750170
# Train Epoch: 1 [26880/43444 (62%)]	Loss: 0.803456
# Train Epoch: 1 [35840/43444 (83%)]	Loss: 0.729769
#
# Test set: Average loss: 0.0039, Accuracy: 9003/10861 (82.89%)
#
# Train Epoch: 2 [0/43444 (0%)]	Loss: 0.413556
# Train Epoch: 2 [8960/43444 (21%)]	Loss: 0.532176
# Train Epoch: 2 [17920/43444 (41%)]	Loss: 0.485940
# Train Epoch: 2 [26880/43444 (62%)]	Loss: 0.495575
# Train Epoch: 2 [35840/43444 (83%)]	Loss: 0.389202
#
# Test set: Average loss: 0.0026, Accuracy: 9597/10861 (88.36%)
#
# Train Epoch: 3 [0/43444 (0%)]	Loss: 0.444076
# Train Epoch: 3 [8960/43444 (21%)]	Loss: 0.333426
# Train Epoch: 3 [17920/43444 (41%)]	Loss: 0.221329
# Train Epoch: 3 [26880/43444 (62%)]	Loss: 0.365915
# Train Epoch: 3 [35840/43444 (83%)]	Loss: 0.315309
#
# Test set: Average loss: 0.0017, Accuracy: 10021/10861 (92.27%)
#
# Train Epoch: 4 [0/43444 (0%)]	Loss: 0.184382
# Train Epoch: 4 [8960/43444 (21%)]	Loss: 0.261497
# Train Epoch: 4 [17920/43444 (41%)]	Loss: 0.231411
# Train Epoch: 4 [26880/43444 (62%)]	Loss: 0.198241
# Train Epoch: 4 [35840/43444 (83%)]	Loss: 0.198728
#
# Test set: Average loss: 0.0014, Accuracy: 10103/10861 (93.02%)
#
# Train Epoch: 5 [0/43444 (0%)]	Loss: 0.092715
# Train Epoch: 5 [8960/43444 (21%)]	Loss: 0.080989
# Train Epoch: 5 [17920/43444 (41%)]	Loss: 0.110478
# Train Epoch: 5 [26880/43444 (62%)]	Loss: 0.087264
# Train Epoch: 5 [35840/43444 (83%)]	Loss: 0.063183
#
# Test set: Average loss: 0.0013, Accuracy: 10191/10861 (93.83%)

# %%
_, ax = plt.subplots(figsize=(10, 5))
ax.plot(np.arange(1, 6).astype(int), loss_values, label="train loss")
ax.plot(np.arange(1, 6).astype(int), accuracy_values, label="test accuracy")
plt.xlabel('Epochs')
plt.ylabel('Loss and Acc')
plt.title('Train Loss and Test Accuracy')
plt.legend()
plt.show()

# %%
summary(model, input_size=(3, 256, 256), batch_size=128)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [128, 16, 254, 254]             448
#               ReLU-2        [128, 16, 254, 254]               0
#             Conv2d-3        [128, 32, 250, 250]          12,832
#               ReLU-4        [128, 32, 250, 250]               0
#          MaxPool2d-5        [128, 32, 125, 125]               0
#             Conv2d-6        [128, 48, 121, 121]          38,448
#               ReLU-7        [128, 48, 121, 121]               0
#          MaxPool2d-8          [128, 48, 60, 60]               0
#             Conv2d-9          [128, 64, 56, 56]          76,864
#              ReLU-10          [128, 64, 56, 56]               0
#         MaxPool2d-11          [128, 64, 28, 28]               0
#            Linear-12                [128, 2048]     102,762,496
#              ReLU-13                [128, 2048]               0
#           Dropout-14                [128, 2048]               0
#            Linear-15                [128, 1024]       2,098,176
#              ReLU-16                [128, 1024]               0
#            Linear-17                  [128, 14]          14,350
# ================================================================
# Total params: 105,003,614
# Trainable params: 105,003,614
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 96.00
# Forward/backward pass size (MB): 8401.01
# Params size (MB): 400.56
# Estimated Total Size (MB): 8897.57
# ----------------------------------------------------------------

# %%
class Net1(nn.Module):
    def __init__(self, out_size):
        super(Net1, self).__init__()
        self.out_size = out_size

        self.conv1 = nn.Conv2d(3, 16, 3, 1)
        self.conv2 = nn.Conv2d(16, 32, 5, 1)
        self.conv3 = nn.Conv2d(32, 48, 5, 1)
        self.conv4 = nn.Conv2d(48, 64, 5, 1)

        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2)
        self.dropout = nn.Dropout(0.5)

        self.fc1 = nn.Linear(64 * 28 * 28, 128) # 50.176 x 128
        self.fc2 = nn.Linear(128, out_size)     #  128 x 14
        # self.fc3 = nn.Linear(1024, out_size)
    
    def forward(self, x):
        # x -> [batch_size, channel, width, height]
        # x -> [128, 3, 256, 256]
        
        x = self.relu(self.conv1(x)) # x -> [128, 16, 254, 254]
        x = self.relu(self.conv2(x)) # x -> [128, 32, 250, 250]
        x = self.pool(x)             # x -> [128, 32, 125, 125]
        x = self.relu(self.conv3(x)) # x -> [128, 48, 121, 121]
        x = self.pool(x)             # x -> [128, 48,  60,  60]
        x = self.relu(self.conv4(x)) # x -> [128, 64,  56,  56]
        x = self.pool(x)             # x -> [128, 64,  28,  28]
        
        x = torch.flatten(x, 1)      # x -> [128, 64 * 28 * 28]
        
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        # x = self.relu(self.fc2(x))
        x = self.fc2(x)
        
        return x

# %%
model1 = Net1(len(leaf_types_map)).to(device)
summary(model1, input_size=(3, 256, 256), batch_size=128)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [128, 16, 254, 254]             448
#               ReLU-2        [128, 16, 254, 254]               0
#             Conv2d-3        [128, 32, 250, 250]          12,832
#               ReLU-4        [128, 32, 250, 250]               0
#          MaxPool2d-5        [128, 32, 125, 125]               0
#             Conv2d-6        [128, 48, 121, 121]          38,448
#               ReLU-7        [128, 48, 121, 121]               0
#          MaxPool2d-8          [128, 48, 60, 60]               0
#             Conv2d-9          [128, 64, 56, 56]          76,864
#              ReLU-10          [128, 64, 56, 56]               0
#         MaxPool2d-11          [128, 64, 28, 28]               0
#            Linear-12                 [128, 128]       6,422,656
#              ReLU-13                 [128, 128]               0
#           Dropout-14                 [128, 128]               0
#            Linear-15                  [128, 14]           1,806
# ================================================================
# Total params: 6,553,054
# Trainable params: 6,553,054
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 96.00
# Forward/backward pass size (MB): 8393.39
# Params size (MB): 25.00
# Estimated Total Size (MB): 8514.39
# ----------------------------------------------------------------

# %%
batch_size = 128

transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = PlantDataset(train_path, transform, leaf_types_map)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

test_dataset = PlantDataset(test_path, transform, leaf_types_map)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net1(len(leaf_types_map)).to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=1, gamma=0.7)

loss_values = []
accuracy_values = []
test(model, device, test_loader, criterion, True)
for epoch in range(5):
    train_loss = train(model, device, train_loader, optimizer, criterion, epoch)
    loss_values.append(train_loss)

    test_acc, confusion_matrix = test(model, device, test_loader, criterion, True)
    accuracy_values.append(test_acc)

    scheduler.step()

torch.save(model.state_dict(), "plant_model.pth")

df_cm = pd.DataFrame(confusion_matrix.numpy(), index=leaf_types, columns=leaf_types)
plt.figure(figsize=(10, 10))
sns.heatmap(df_cm, annot=True)
plt.show()
# Out:
# Test set: Average loss: 0.0204, Accuracy: 890/10861 (8.19%)
#
# Train Epoch: 1 [0/43444 (0%)]	Loss: 2.640241
# Train Epoch: 1 [8960/43444 (21%)]	Loss: 1.412566
# Train Epoch: 1 [17920/43444 (41%)]	Loss: 1.164609
# Train Epoch: 1 [26880/43444 (62%)]	Loss: 0.792943
# Train Epoch: 1 [35840/43444 (83%)]	Loss: 0.506253
#
# Test set: Average loss: 0.0039, Accuracy: 9011/10861 (82.97%)
#
# Train Epoch: 2 [0/43444 (0%)]	Loss: 0.633921
# Train Epoch: 2 [8960/43444 (21%)]	Loss: 0.397069
# Train Epoch: 2 [17920/43444 (41%)]	Loss: 0.728781
# Train Epoch: 2 [26880/43444 (62%)]	Loss: 0.589984
# Train Epoch: 2 [35840/43444 (83%)]	Loss: 0.666972
#
# Test set: Average loss: 0.0027, Accuracy: 9604/10861 (88.43%)
#
# Train Epoch: 3 [0/43444 (0%)]	Loss: 0.585039
# Train Epoch: 3 [8960/43444 (21%)]	Loss: 0.404915
# Train Epoch: 3 [17920/43444 (41%)]	Loss: 0.508899
# Train Epoch: 3 [26880/43444 (62%)]	Loss: 0.487047
# Train Epoch: 3 [35840/43444 (83%)]	Loss: 0.312189
#
# Test set: Average loss: 0.0020, Accuracy: 9890/10861 (91.06%)
#
# Train Epoch: 4 [0/43444 (0%)]	Loss: 0.340628
# Train Epoch: 4 [8960/43444 (21%)]	Loss: 0.340887
# Train Epoch: 4 [17920/43444 (41%)]	Loss: 0.206303
# Train Epoch: 4 [26880/43444 (62%)]	Loss: 0.326404
# Train Epoch: 4 [35840/43444 (83%)]	Loss: 0.178703
#
# Test set: Average loss: 0.0016, Accuracy: 10052/10861 (92.55%)
#
# Train Epoch: 5 [0/43444 (0%)]	Loss: 0.156275
# Train Epoch: 5 [8960/43444 (21%)]	Loss: 0.297450
# Train Epoch: 5 [17920/43444 (41%)]	Loss: 0.099438
# Train Epoch: 5 [26880/43444 (62%)]	Loss: 0.187917
# Train Epoch: 5 [35840/43444 (83%)]	Loss: 0.244827
#
# Test set: Average loss: 0.0014, Accuracy: 10124/10861 (93.21%)

# %%
_, ax = plt.subplots(figsize=(10, 5))
ax.plot(np.arange(1, 6).astype(int), loss_values, label="train loss")
ax.plot(np.arange(1, 6).astype(int), accuracy_values, label="test accuracy")
plt.xlabel('Epochs')
plt.ylabel('Loss and Acc')
plt.title('Train Loss and Test Accuracy')
plt.legend()
plt.show()

# %%
summary(model, input_size=(3, 256, 256), batch_size=128)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [128, 16, 254, 254]             448
#               ReLU-2        [128, 16, 254, 254]               0
#             Conv2d-3        [128, 32, 250, 250]          12,832
#               ReLU-4        [128, 32, 250, 250]               0
#          MaxPool2d-5        [128, 32, 125, 125]               0
#             Conv2d-6        [128, 48, 121, 121]          38,448
#               ReLU-7        [128, 48, 121, 121]               0
#          MaxPool2d-8          [128, 48, 60, 60]               0
#             Conv2d-9          [128, 64, 56, 56]          76,864
#              ReLU-10          [128, 64, 56, 56]               0
#         MaxPool2d-11          [128, 64, 28, 28]               0
#            Linear-12                 [128, 128]       6,422,656
#              ReLU-13                 [128, 128]               0
#           Dropout-14                 [128, 128]               0
#            Linear-15                  [128, 14]           1,806
# ================================================================
# Total params: 6,553,054
# Trainable params: 6,553,054
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 96.00
# Forward/backward pass size (MB): 8393.39
# Params size (MB): 25.00
# Estimated Total Size (MB): 8514.39
# ----------------------------------------------------------------

# %% [markdown]
# ## transfer learning

# %%
batch_size = 128

transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = PlantDataset(train_path, transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

test_dataset = PlantDataset(test_path, transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = models.resnet18(pretrained=True)
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(classes))
model.layer4[1].conv2.weight.requires_grad = True

for name, param in model.named_parameters():
    if param.requires_grad:
        print("param.requires_grad:", name)

model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=1, gamma=0.7)

loss_values = []
accuracy_values = []
test(model, device, test_loader, criterion)
for epoch in range(5):
    train_loss = train(model, device, train_loader, optimizer, criterion, epoch)
    loss_values.append(train_loss)

    test_acc, confusion_matrix = test(model, device, test_loader, criterion)
    accuracy_values.append(test_acc)

    scheduler.step()

torch.save(model.state_dict(), "scene_model.pth")

df_cm = pd.DataFrame(confusion_matrix.numpy(), index=classes, columns=classes)
plt.figure(figsize=(10, 10))
sns.heatmap(df_cm, annot=True)
plt.show()
# Out:
# param.requires_grad: layer4.1.conv2.weight
# param.requires_grad: fc.weight
# param.requires_grad: fc.bias
#
# Test set: Average loss: 0.0057, Accuracy: 5214/10861 (48%)
#
# Train Epoch: 1 [0/43444 (0%)]	Loss: 0.789341
# Train Epoch: 1 [8960/43444 (21%)]	Loss: 0.048481
# Train Epoch: 1 [17920/43444 (41%)]	Loss: 0.025774
# Train Epoch: 1 [26880/43444 (62%)]	Loss: 0.043765
# Train Epoch: 1 [35840/43444 (83%)]	Loss: 0.026566
#
# Test set: Average loss: 0.0002, Accuracy: 10638/10861 (98%)
#
# Train Epoch: 2 [0/43444 (0%)]	Loss: 0.015302
# Train Epoch: 2 [8960/43444 (21%)]	Loss: 0.020730
# Train Epoch: 2 [17920/43444 (41%)]	Loss: 0.014708
# Train Epoch: 2 [26880/43444 (62%)]	Loss: 0.016998
# Train Epoch: 2 [35840/43444 (83%)]	Loss: 0.023106
#
# Test set: Average loss: 0.0002, Accuracy: 10682/10861 (98%)
#
# Train Epoch: 3 [0/43444 (0%)]	Loss: 0.010253
# Train Epoch: 3 [8960/43444 (21%)]	Loss: 0.002607
# Train Epoch: 3 [17920/43444 (41%)]	Loss: 0.014186
# Train Epoch: 3 [26880/43444 (62%)]	Loss: 0.004538
# Train Epoch: 3 [35840/43444 (83%)]	Loss: 0.032451
#
# Test set: Average loss: 0.0001, Accuracy: 10690/10861 (98%)
#
# Train Epoch: 4 [0/43444 (0%)]	Loss: 0.017187
# Train Epoch: 4 [8960/43444 (21%)]	Loss: 0.004990
# Train Epoch: 4 [17920/43444 (41%)]	Loss: 0.016766
# Train Epoch: 4 [26880/43444 (62%)]	Loss: 0.029381
# Train Epoch: 4 [35840/43444 (83%)]	Loss: 0.006516
#
# Test set: Average loss: 0.0001, Accuracy: 10694/10861 (98%)
#
# Train Epoch: 5 [0/43444 (0%)]	Loss: 0.005738
# Train Epoch: 5 [8960/43444 (21%)]	Loss: 0.001581
# Train Epoch: 5 [17920/43444 (41%)]	Loss: 0.001742
# Train Epoch: 5 [26880/43444 (62%)]	Loss: 0.005301
# Train Epoch: 5 [35840/43444 (83%)]	Loss: 0.005793
#
# Test set: Average loss: 0.0001, Accuracy: 10696/10861 (98%)

# %%
_, ax = plt.subplots(figsize=(10, 5))
ax.plot(np.arange(1, 6).astype(int), loss_values, label="train loss")
ax.plot(np.arange(1, 6).astype(int), accuracy_values, label="test accuracy")
plt.xlabel('Epochs')
plt.ylabel('Loss and Acc')
plt.title('Train Loss and Test Accuracy')
plt.legend()
plt.show()

# %%
summary(model, input_size=(3, 256, 256), batch_size=128)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [128, 64, 128, 128]           9,408
#        BatchNorm2d-2        [128, 64, 128, 128]             128
#               ReLU-3        [128, 64, 128, 128]               0
#          MaxPool2d-4          [128, 64, 64, 64]               0
#             Conv2d-5          [128, 64, 64, 64]          36,864
#        BatchNorm2d-6          [128, 64, 64, 64]             128
#               ReLU-7          [128, 64, 64, 64]               0
#             Conv2d-8          [128, 64, 64, 64]          36,864
#        BatchNorm2d-9          [128, 64, 64, 64]             128
#              ReLU-10          [128, 64, 64, 64]               0
#        BasicBlock-11          [128, 64, 64, 64]               0
#            Conv2d-12          [128, 64, 64, 64]          36,864
#       BatchNorm2d-13          [128, 64, 64, 64]             128
#              ReLU-14          [128, 64, 64, 64]               0
#            Conv2d-15          [128, 64, 64, 64]          36,864
#       BatchNorm2d-16          [128, 64, 64, 64]             128
#              ReLU-17          [128, 64, 64, 64]               0
#        BasicBlock-18          [128, 64, 64, 64]               0
#            Conv2d-19         [128, 128, 32, 32]          73,728
#       BatchNorm2d-20         [128, 128, 32, 32]             256
#              ReLU-21         [128, 128, 32, 32]               0
#            Conv2d-22         [128, 128, 32, 32]         147,456
#       BatchNorm2d-23         [128, 128, 32, 32]             256
#            Conv2d-24         [128, 128, 32, 32]           8,192
#       BatchNorm2d-25         [128, 128, 32, 32]             256
#              ReLU-26         [128, 128, 32, 32]               0
#        BasicBlock-27         [128, 128, 32, 32]               0
#            Conv2d-28         [128, 128, 32, 32]         147,456
#       BatchNorm2d-29         [128, 128, 32, 32]             256
#              ReLU-30         [128, 128, 32, 32]               0
#            Conv2d-31         [128, 128, 32, 32]         147,456
#       BatchNorm2d-32         [128, 128, 32, 32]             256
#              ReLU-33         [128, 128, 32, 32]               0
#        BasicBlock-34         [128, 128, 32, 32]               0
#            Conv2d-35         [128, 256, 16, 16]         294,912
#       BatchNorm2d-36         [128, 256, 16, 16]             512
#              ReLU-37         [128, 256, 16, 16]               0
#            Conv2d-38         [128, 256, 16, 16]         589,824
#       BatchNorm2d-39         [128, 256, 16, 16]             512
#            Conv2d-40         [128, 256, 16, 16]          32,768
#       BatchNorm2d-41         [128, 256, 16, 16]             512
#              ReLU-42         [128, 256, 16, 16]               0
#        BasicBlock-43         [128, 256, 16, 16]               0
#            Conv2d-44         [128, 256, 16, 16]         589,824
#       BatchNorm2d-45         [128, 256, 16, 16]             512
#              ReLU-46         [128, 256, 16, 16]               0
#            Conv2d-47         [128, 256, 16, 16]         589,824
#       BatchNorm2d-48         [128, 256, 16, 16]             512
#              ReLU-49         [128, 256, 16, 16]               0
#        BasicBlock-50         [128, 256, 16, 16]               0
#            Conv2d-51           [128, 512, 8, 8]       1,179,648
#       BatchNorm2d-52           [128, 512, 8, 8]           1,024
#              ReLU-53           [128, 512, 8, 8]               0
#            Conv2d-54           [128, 512, 8, 8]       2,359,296
#       BatchNorm2d-55           [128, 512, 8, 8]           1,024
#            Conv2d-56           [128, 512, 8, 8]         131,072
#       BatchNorm2d-57           [128, 512, 8, 8]           1,024
#              ReLU-58           [128, 512, 8, 8]               0
#        BasicBlock-59           [128, 512, 8, 8]               0
#            Conv2d-60           [128, 512, 8, 8]       2,359,296
#       BatchNorm2d-61           [128, 512, 8, 8]           1,024
#              ReLU-62           [128, 512, 8, 8]               0
#            Conv2d-63           [128, 512, 8, 8]       2,359,296
#       BatchNorm2d-64           [128, 512, 8, 8]           1,024
#              ReLU-65           [128, 512, 8, 8]               0
#        BasicBlock-66           [128, 512, 8, 8]               0
# AdaptiveAvgPool2d-67           [128, 512, 1, 1]               0
#            Linear-68                   [128, 2]           1,026
# ================================================================
# Total params: 11,177,538
# Trainable params: 2,360,322
# Non-trainable params: 8,817,216
# ----------------------------------------------------------------
# Input size (MB): 96.00
# Forward/backward pass size (MB): 10496.50
# Params size (MB): 42.64
# Estimated Total Size (MB): 10635.14
# ----------------------------------------------------------------
